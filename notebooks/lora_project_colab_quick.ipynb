# %% [markdown]
# # LoRA Final Project (Colab Quick Mode)
#
# This notebook runs a fast smoke pipeline:
# - install dependencies
# - run reduced-step experiments
# - generate poster-style figures quickly
#
# Use this first to validate setup before the full run.

# %%
import os
IN_COLAB = 'COLAB_GPU' in os.environ
print('Running in Colab:', IN_COLAB)
if IN_COLAB:
    # !nvidia-smi || true

# %%
# Replace with your repo URL.
REPO_URL = "https://github.com/<your-username>/<your-repo>.git"
PROJECT_DIR = "/content/deep-learning-final-project"

if os.path.exists(PROJECT_DIR):
    print('Project directory already exists:', PROJECT_DIR)
else:
    # !git clone "$REPO_URL" "$PROJECT_DIR"

os.chdir(PROJECT_DIR)
print('Using project dir:', os.getcwd())

# %%
# !python -m pip install --upgrade pip
# !pip install -r requirements.txt

# %%
# !chmod +x scripts/run_quick.sh
# !bash scripts/run_quick.sh

# %%
# !find results/figures_quick -maxdepth 1 -type f | sort
